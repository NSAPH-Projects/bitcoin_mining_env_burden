# %%
import pandas as pd 
import sys
import os 
import warnings
warnings.filterwarnings('ignore')

sys.path.append(os.path.abspath(os.path.join('../src')))

from emission_calculator import complete_dataset

# %%
df_complete_2022_2023 = complete_dataset()
# Out:
# whinstone_us_rockdale_tx
# genesis_pyote_tx
# compute_north_upton_tx
# bitdeer_rockdale_tx
# core_scientific_calvert_city_ky
# massena_complex_massena_ny
# core_scientific_dalton_green_dalton_ga
# atlas_power_williston_nd
# cipher_odessa_tx
# core_scientific_cherokee_county_facility_marble_nc_1
# core_scientific_cherokee_county_facility_marble_nc_2
# argo_afton_tx
# poolin__pecos_tx
# compute_north_buffalo_county_facility_kearney_ne
# core_scientific_grand_forks_county_facility_grand_forks_nd
# merkle_standard_pend_oreille_county_facility_usk_wa
# merkle_standard_south_carolina
# applied_blockchain_jamestown_nd
# mawson_infrastructure_group_midland_pa
# core_scientific_pecos_tx
# sangha_systems_hennepin_il
# cleanspark_sandersville_ga
# digihost_tonawanda_ny
# atlas_power_butte_mt
# core_scientific_denton_tx
# terawulf_lake_mariner_somerset_ny
# bitdeer_knoxville_tn
# aboutbit_sullivan_county_facility_merom_in
# viking_data_centers_oh
# greenidge_generation_dresden_ny
# ...

# %%
df_complete_2022_2023 = pd.read_csv('../data/intermediate/df_complete_2022_2023.csv')

# %%
df_complete_2022_2023.head(100)
# Out:
#                                          miner plant_unit      LAT      LON  \
# 0   aboutbit_sullivan_county_facility_merom_in     1001_1  39.9242 -87.4244
# 1   aboutbit_sullivan_county_facility_merom_in     1001_1  39.9242 -87.4244
# 2   aboutbit_sullivan_county_facility_merom_in     1001_1  39.9242 -87.4244
# 3   aboutbit_sullivan_county_facility_merom_in     1001_1  39.9242 -87.4244
# 4   aboutbit_sullivan_county_facility_merom_in     1001_1  39.9242 -87.4244
# ..                                         ...        ...      ...      ...
# 95  aboutbit_sullivan_county_facility_merom_in     1012_2  37.9111 -87.3275
# 96  aboutbit_sullivan_county_facility_merom_in     1012_3  37.9111 -87.3275
# 97  aboutbit_sullivan_county_facility_merom_in     1012_3  37.9111 -87.3275
# 98  aboutbit_sullivan_county_facility_merom_in     1012_3  37.9111 -87.3275
# 99  aboutbit_sullivan_county_facility_merom_in     1012_3  37.9111 -87.3275
#
# ...

# %%
df_complete_2022_2023.shape
# Out:
# (97255, 16)
