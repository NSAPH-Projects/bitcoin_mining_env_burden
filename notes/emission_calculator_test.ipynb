# %%
import sys
import os 
import warnings
warnings.filterwarnings('ignore')

sys.path.append(os.path.abspath(os.path.join('../src')))

from emission_calculator import find_miner_emissions

# %%
#Example usage for Miner 'whinstone_us_rockdale_tx'
emissions_ex1 = find_miner_emissions(miner = 'whinstone_us_rockdale_tx', period = 'daily')#['marginalMW_NO_wattime].sum()

# %%
emissions_ex1.shape
# Out:
# (388810, 22)

# %%
emissions_ex1.head(100)
# Out:
#     year  month  day                     miner   plant_unit  height  \
# 0   2020      1    1  whinstone_us_rockdale_tx  10298_CG801  28.956
# 1   2020      1    2  whinstone_us_rockdale_tx  10298_CG801  28.956
# 2   2020      1    3  whinstone_us_rockdale_tx  10298_CG801  28.956
# 3   2020      1    4  whinstone_us_rockdale_tx  10298_CG801  28.956
# 4   2020      1    5  whinstone_us_rockdale_tx  10298_CG801  28.956
# ..   ...    ...  ...                       ...          ...     ...
# 95  2020      4    5  whinstone_us_rockdale_tx  10298_CG801  28.956
# 96  2020      4    6  whinstone_us_rockdale_tx  10298_CG801  28.956
# 97  2020      4    7  whinstone_us_rockdale_tx  10298_CG801  28.956
# 98  2020      4    8  whinstone_us_rockdale_tx  10298_CG801  28.956
# 99  2020      4    9  whinstone_us_rockdale_tx  10298_CG801  28.956
#
#           temp    diam  velocity  PlumeHeight  ...  marginalMW_wattime  \
# 0   437.038889  4.4196  22.95144   172.812248  ...            1.283535
# ...

# %%
emissions_ex2 = find_miner_emissions(miner = 'whinstone_us_rockdale_tx', period = 'monthly', wattime_data = True)

# %%
emissions_ex2.shape
# Out:
# (16038, 11)

# %%
emissions_ex2.head(100)
# Out:
#     year  month                     miner   plant_unit      LAT      LON  \
# 0   2019      2  whinstone_us_rockdale_tx  10298_CG801  29.6225 -95.0458
# 1   2019      3  whinstone_us_rockdale_tx  10298_CG801  29.6225 -95.0458
# 2   2019      4  whinstone_us_rockdale_tx  10298_CG801  29.6225 -95.0458
# 3   2019      5  whinstone_us_rockdale_tx  10298_CG801  29.6225 -95.0458
# 4   2019      6  whinstone_us_rockdale_tx  10298_CG801  29.6225 -95.0458
# ..   ...    ...                       ...          ...      ...      ...
# 95  2022      6  whinstone_us_rockdale_tx  10298_CG802  29.6225 -95.0458
# 96  2022      7  whinstone_us_rockdale_tx  10298_CG802  29.6225 -95.0458
# 97  2022      8  whinstone_us_rockdale_tx  10298_CG802  29.6225 -95.0458
# 98  2022      9  whinstone_us_rockdale_tx  10298_CG802  29.6225 -95.0458
# 99  2022     10  whinstone_us_rockdale_tx  10298_CG802  29.6225 -95.0458
#
#     marginalMW_wattime  co2_lbs_wattime  nox_lbs_wattime  so2_lbs_wattime  \
# ...
